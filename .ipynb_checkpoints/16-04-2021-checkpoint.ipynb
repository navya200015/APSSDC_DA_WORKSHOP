# %% [markdown]
# # robust

# %%
import pandas as pd

# %%
a1=pd.read_csv("https://raw.githubusercontent.com/nagamounika5/Datasets/master/Advertisement.csv")
a1
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# 5             6    8.7   48.9       75.0    7.2
# 6             7   57.5   32.8       23.5   11.8
# 7             8  120.2   19.6       11.6   13.2
# 8             9    8.6    2.1        1.0    4.8
# 9            10  199.8    2.6       21.2   10.6
# 10           11   66.1    5.8       24.2    8.6
# 11           12  214.7   24.0        4.0   17.4
# 12           13   23.8   35.1       65.9    9.2
# 13           14   97.5    7.6        7.2    9.7
# 14           15  204.1   32.9       46.0   19.0
# 15           16  195.4   47.7       52.9   22.4
# 16           17   67.8   36.6      114.0   12.5
# 17           18  281.4   39.6       55.8   24.4
# 18           19   69.2   20.5       18.3   11.3
# ...

# %%
a1.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
from sklearn.preprocessing import RobustScaler

# %%
pd = RobustScaler()
pd
# Out:
# RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#        with_scaling=True)

# %%
rs2=pd.fit_transform(a1)
rs2
# Out:
# array([[-1.00000000e+00,  5.56247837e-01,  5.61205273e-01,
#          1.34312210e+00,  1.30960854e+00],
#        [-9.89949749e-01, -7.28625822e-01,  6.17702448e-01,
#          5.98145286e-01, -3.55871886e-01],
#        [-9.79899497e-01, -9.17618553e-01,  8.66290019e-01,
#          1.34621329e+00, -5.12455516e-01],
#        [-9.69849246e-01,  1.21149187e-02,  6.93032015e-01,
#          1.01236476e+00,  7.97153025e-01],
#        [-9.59798995e-01,  2.14953271e-01, -4.55743879e-01,
#          1.00927357e+00,  0.00000000e+00],
#        [-9.49748744e-01, -9.76462444e-01,  9.79284369e-01,
#          1.52241113e+00, -8.11387900e-01],
#        [-9.39698492e-01, -6.38629283e-01,  3.72881356e-01,
#         -6.95517774e-02, -1.56583630e-01],
#        [-9.29648241e-01, -2.04569055e-01, -1.24293785e-01,
#         -4.37403400e-01,  4.27046263e-02],
#        [-9.19597990e-01, -9.77154725e-01, -7.83427495e-01,
#         -7.65069552e-01, -1.15302491e+00],
# ...

# %%
rs2=pd.DataFrame(rs2,columns=a1.columns)
rs2
# Out:
#            TV     radio  newspaper     sales
# 0    0.556248  0.561205   1.343122  1.309609
# 1   -0.728626  0.617702   0.598145 -0.355872
# 2   -0.917619  0.866290   1.346213 -0.512456
# 3    0.012115  0.693032   1.012365  0.797153
# 4    0.214953 -0.455744   1.009274  0.000000
# 5   -0.976462  0.979284   1.522411 -0.811388
# 6   -0.638629  0.372881  -0.069552 -0.156584
# 7   -0.204569 -0.124294  -0.437403  0.042705
# 8   -0.977155 -0.783427  -0.765070 -1.153025
# 9    0.346487 -0.764595  -0.140649 -0.327402
# 10  -0.579093 -0.644068  -0.047913 -0.612100
# 11   0.449637  0.041431  -0.672334  0.640569
# 12  -0.871928  0.459510   1.241113 -0.526690
# 13  -0.361717 -0.576271  -0.573416 -0.455516
# 14   0.376255  0.376648   0.625966  0.868327
# 15   0.316026  0.934087   0.839258  1.352313
# 16  -0.567324  0.516008   2.727975 -0.056940
# 17   0.911388  0.629002   0.928903  1.637011
# 18  -0.557632 -0.090395  -0.230294 -0.227758
# 19  -0.016961  0.037665  -0.205564  0.241993
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fig, (ax1,ax2)=plt.subplots(ncols=2,figsize=(9,5))

# %%
fig, (ax1,ax2)=plt.subplots(ncols=2,figsize=(9,5))
sns.kdeplot(a1['TV'],ax=ax1)
sns.kdeplot(a1['radio'],ax=ax1)
sns.kdeplot(a1['newspaper'],ax=ax1)
sns.kdeplot(a1['sales'],ax=ax1)


sns.kdeplot(rs2['TV'],ax=ax2)
sns.kdeplot(rs2['radio'],ax=ax2)
sns.kdeplot(rs2['newspaper'],ax=ax2)
sns.kdeplot(rs2['sales'],ax=ax2)

# %%
a1.quantile(0.25)
# Out:
# TV           74.375
# radio         9.975
# newspaper    12.750
# sales        10.375
# Name: 0.25, dtype: float64

# %% [markdown]
# # standard scaler
# most commonly used scaling technique.it scales between 0 to mean

# %% [markdown]
# ### standard scalar formula
# # Xi  - mean(x)
# # --------------------------
# #     std(x)

# %%
# step1:import model
# step2:initialize model  into new object
# step3:fit the model to dataset
# step4:convert array values into dataframe

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss=StandardScaler()
ss
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
ss2=ss.fit_transform(a1)
ss2
# Out:
# array([[ 9.69852266e-01,  9.81522472e-01,  1.77894547e+00,
#          1.55205313e+00],
#        [-1.19737623e+00,  1.08280781e+00,  6.69578760e-01,
#         -6.96046111e-01],
#        [-1.51615499e+00,  1.52846331e+00,  1.78354865e+00,
#         -9.07405869e-01],
#        [ 5.20496822e-02,  1.21785493e+00,  1.28640506e+00,
#          8.60330287e-01],
#        [ 3.94182198e-01, -8.41613655e-01,  1.28180188e+00,
#         -2.15683025e-01],
#        [-1.61540845e+00,  1.73103399e+00,  2.04592999e+00,
#         -1.31091086e+00],
#        [-1.04557682e+00,  6.43904671e-01, -3.24708413e-01,
#         -4.27042783e-01],
#        [-3.13436589e-01, -2.47406325e-01, -8.72486994e-01,
#         -1.58039455e-01],
#        [-1.61657614e+00, -1.42906863e+00, -1.36042422e+00,
#         -1.77205942e+00],
#        [ 6.16042873e-01, -1.39530685e+00, -4.30581584e-01,
#         -6.57617064e-01],
#        [-9.45155670e-01, -1.17923146e+00, -2.92486143e-01,
#         -1.04190753e+00],
# ...

# %%
ss2=pd.DataFrame(ss2,columns=a1.columns)
ss2
# Out:
#            TV     radio  newspaper     sales
# 0    0.969852  0.981522   1.778945  1.552053
# 1   -1.197376  1.082808   0.669579 -0.696046
# 2   -1.516155  1.528463   1.783549 -0.907406
# 3    0.052050  1.217855   1.286405  0.860330
# 4    0.394182 -0.841614   1.281802 -0.215683
# 5   -1.615408  1.731034   2.045930 -1.310911
# 6   -1.045577  0.643905  -0.324708 -0.427043
# 7   -0.313437 -0.247406  -0.872487 -0.158039
# 8   -1.616576 -1.429069  -1.360424 -1.772059
# 9    0.616043 -1.395307  -0.430582 -0.657617
# 10  -0.945156 -1.179231  -0.292486 -1.041908
# 11   0.790028  0.049697  -1.222329  0.648971
# 12  -1.439088  0.799209   1.627040 -0.926620
# 13  -0.578502 -1.057689  -1.075027 -0.830548
# 14   0.666253  0.650657   0.711007  0.956403
# 15   0.564665  1.650006   1.028627  1.609697
# 16  -0.925305  0.900494   3.841171 -0.292541
# 17   1.568876  1.103065   1.162119  1.993987
# 18  -0.908957 -0.186635  -0.564074 -0.523115
# 19   0.003007  0.042945  -0.527248  0.110964
# ...

# %%
a1.boxplot()
