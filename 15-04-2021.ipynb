# %%
import pandas as rs

# %%
data=rs.read_csv("https://raw.githubusercontent.com/AP-State-Skill-Development-Corporation/Datasets/master/Data%20Analysis/Advertising.csv")
data
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# 5             6    8.7   48.9       75.0    7.2
# 6             7   57.5   32.8       23.5   11.8
# 7             8  120.2   19.6       11.6   13.2
# 8             9    8.6    2.1        1.0    4.8
# 9            10  199.8    2.6       21.2   10.6
# 10           11   66.1    5.8       24.2    8.6
# 11           12  214.7   24.0        4.0   17.4
# 12           13   23.8   35.1       65.9    9.2
# 13           14   97.5    7.6        7.2    9.7
# 14           15  204.1   32.9       46.0   19.0
# 15           16  195.4   47.7       52.9   22.4
# 16           17   67.8   36.6      114.0   12.5
# 17           18  281.4   39.6       55.8   24.4
# 18           19   69.2   20.5       18.3   11.3
# ...

# %%
data=rs.read_csv("https://raw.githubusercontent.com/AP-State-Skill-Development-Corporation/Datasets/master/Data%20Analysis/Advertising.csv")
data.head(3)
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3

# %%
data=rs.read_csv("https://raw.githubusercontent.com/AP-State-Skill-Development-Corporation/Datasets/master/Data%20Analysis/Advertising.csv")
data.tail(3)
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %%
data.shape
# Out:
# (200, 5)

# %%
data.describe()
# Out:
#        Unnamed: 0          TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
# Unnamed: 0    200 non-null int64
# TV            200 non-null float64
# radio         200 non-null float64
# newspaper     200 non-null float64
# sales         200 non-null float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
data.isna()
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0         False  False  False      False  False
# 1         False  False  False      False  False
# 2         False  False  False      False  False
# 3         False  False  False      False  False
# 4         False  False  False      False  False
# 5         False  False  False      False  False
# 6         False  False  False      False  False
# 7         False  False  False      False  False
# 8         False  False  False      False  False
# 9         False  False  False      False  False
# 10        False  False  False      False  False
# 11        False  False  False      False  False
# 12        False  False  False      False  False
# 13        False  False  False      False  False
# 14        False  False  False      False  False
# 15        False  False  False      False  False
# 16        False  False  False      False  False
# 17        False  False  False      False  False
# 18        False  False  False      False  False
# ...

# %%
data.isna().sum()
# Out:
# Unnamed: 0    0
# TV            0
# radio         0
# newspaper     0
# sales         0
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# radio         0
# newspaper     0
# sales         0
# dtype: int64

# %%
data.isna().sum().sum()
# Out:
# 0

# %%
data.head(3)
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3

# %%
data.iloc[0,3]
# Out:
# 69.2

# %%
data.loc[0]
# Out:
# Unnamed: 0      1.0
# TV            230.1
# radio          37.8
# newspaper      69.2
# sales          22.1
# Name: 0, dtype: float64

# %%
data.loc[0][3]
# Out:
# 69.2

# %%
data.loc[0,'newspaper']
# Out:
# 69.2

# %%
tab_data=rs.read_table("https://raw.githubusercontent.com/AP-State-Skill-Development-Corporation/Datasets/master/Data%20Analysis/chipotle.tsv.txt")
tab_data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 9            5         1                          Steak Burrito
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 13           7         1                           Chicken Bowl
# ...

# %%
tab_data.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
tab_data.isna().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
tab_data.drop('choice_description',axis=1)
# Out:
#       order_id  quantity                              item_name item_price
# 0            1         1           Chips and Fresh Tomato Salsa     $2.39
# 1            1         1                                   Izze     $3.39
# 2            1         1                       Nantucket Nectar     $3.39
# 3            1         1  Chips and Tomatillo-Green Chili Salsa     $2.39
# 4            2         2                           Chicken Bowl    $16.98
# 5            3         1                           Chicken Bowl    $10.98
# 6            3         1                          Side of Chips     $1.69
# 7            4         1                          Steak Burrito    $11.75
# 8            4         1                       Steak Soft Tacos     $9.25
# 9            5         1                          Steak Burrito     $9.25
# 10           5         1                    Chips and Guacamole     $4.45
# 11           6         1                   Chicken Crispy Tacos     $8.75
# ...

# %%
tab_data.head(3)
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa                NaN
# 1         1         1                          Izze       [Clementine]
# 2         1         1              Nantucket Nectar            [Apple]
#
#   item_price
# 0     $2.39
# 1     $3.39
# 2     $3.39

# %%
tab_data.drop('choice_description',axis=0,inplace=True)

# %%
tab_data.set_index('item_name')
# Out:
#                                        order_id  quantity item_price
# item_name
# Chips and Fresh Tomato Salsa                  1         1     $2.39
# Izze                                          1         1     $3.39
# Nantucket Nectar                              1         1     $3.39
# Chips and Tomatillo-Green Chili Salsa         1         1     $2.39
# Chicken Bowl                                  2         2    $16.98
# Chicken Bowl                                  3         1    $10.98
# Side of Chips                                 3         1     $1.69
# Steak Burrito                                 4         1    $11.75
# Steak Soft Tacos                              4         1     $9.25
# Steak Burrito                                 5         1     $9.25
# Chips and Guacamole                           5         1     $4.45
# Chicken Crispy Tacos                          6         1     $8.75
# Chicken Soft Tacos                            6         1     $8.75
# ...

# %%
tab_data.set_index('item_name',inplace=True)

# %%
tab_data.head(3)
# Out:
#                               order_id  quantity item_price
# item_name
# Chips and Fresh Tomato Salsa         1         1     $2.39
# Izze                                 1         1     $3.39
# Nantucket Nectar                     1         1     $3.39

# %%
dia_data=rs.read_csv("https://raw.githubusercontent.com/AP-State-Skill-Development-Corporation/Datasets/master/Classification/diabetes.csv")
dia_data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
dia_data.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
dia_data.shape
# Out:
# (768, 9)

# %%
dia_data.head(3)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1

# %%
dia_data.Outcome.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
dia_data.Outcome.unique().sum()
# Out:
# 1

# %%
dia_data[dia_data['Outcome']==1].count()
# Out:
# Pregnancies                 268
# Glucose                     268
# BloodPressure               268
# SkinThickness               268
# Insulin                     268
# BMI                         268
# DiabetesPedigreeFunction    268
# Age                         268
# Outcome                     268
# dtype: int64

# %%
dia_data[dia_data['Outcome']==0].count()
# Out:
# Pregnancies                 500
# Glucose                     500
# BloodPressure               500
# SkinThickness               500
# Insulin                     500
# BMI                         500
# DiabetesPedigreeFunction    500
# Age                         500
# Outcome                     500
# dtype: int64

# %%
tdata=rs.read_csv("https://raw.githubusercontent.com/AP-State-Skill-Development-Corporation/Datasets/master/Classification/titanic.csv")
tdata
# Out:
#      survived  pclass                                               name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# 6           0       1                            McCarthy, Mr. Timothy J
# 7           0       3                     Palsson, Master. Gosta Leonard
# 8           1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9           1       2                Nasser, Mrs. Nicholas (Adele Achem)
# 10          1       3                    Sandstrom, Miss. Marguerite Rut
# 11          1       1                           Bonnell, Miss. Elizabeth
# ...

# %%
tdata.columns
# Out:
# Index(['survived', 'pclass', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked'],
#       dtype='object')

# %%
tdata=rs.read_csv("https://raw.githubusercontent.com/AP-State-Skill-Development-Corporation/Datasets/master/Classification/titanic.csv")
tdata.head()
# Out:
#    survived  pclass                                               name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       sex   age  sibsp  parch            ticket     fare cabin embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
tdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
# survived    891 non-null int64
# pclass      891 non-null int64
# name        891 non-null object
# sex         891 non-null object
# age         714 non-null float64
# sibsp       891 non-null int64
# parch       891 non-null int64
# ticket      891 non-null object
# fare        891 non-null float64
# cabin       204 non-null object
# embarked    889 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 76.6+ KB

# %%
tdata.isna().sum()
# Out:
# survived      0
# pclass        0
# name          0
# sex           0
# age         177
# sibsp         0
# parch         0
# ticket        0
# fare          0
# cabin       687
# embarked      2
# dtype: int64

# %%
tdata['age'].unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
tdata['age'].fillna(tdata['age'].mean())
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
# 5      29.699118
# 6      54.000000
# 7       2.000000
# 8      27.000000
# 9      14.000000
# 10      4.000000
# 11     58.000000
# 12     20.000000
# 13     39.000000
# 14     14.000000
# 15     55.000000
# 16      2.000000
# 17     29.699118
# 18     31.000000
# 19     29.699118
# 20     35.000000
# 21     34.000000
# 22     15.000000
# 23     28.000000
# 24      8.000000
# 25     38.000000
# 26     29.699118
# 27     19.000000
# 28     29.699118
# 29     29.699118
#          ...
# 861    21.000000
# 862    48.000000
# 863    29.699118
# 864    24.000000
# 865    42.000000
# 866    27.000000
# 867    31.000000
# 868    29.699118
# 869     4.000000
# 870    26.000000
# 871    47.000000
# 872    33.000000
# 873    47.000000
# 874    28.000000
# 875    15.000000
# 876    20.000000
# 877    19.000000
# 878    29.699118
# 879    56.000000
# 880    25.000000
# 881    33.000000
# ...

# %%
tdata['cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
tdata.drop('cabin',axis=0,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-4754bfb40fae> in <module>()
# ----> 1 tdata.drop('cabin',axis=0,inplace=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    2528         for axis, labels in axes.items():
#    2529             if labels is not None:
# -> 2530                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    2531
#    2532         if inplace:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    2560                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2561             else:
# -> 2562                 new_axis = axis.drop(labels, errors=errors)
#    2563             dropped = self.reindex(**{axis_name: new_axis})
#    2564             try:
#
# ...

# %%
tdata[tdata['embarked']=='S'].count()
# Out:
# survived    644
# pclass      644
# name        644
# sex         644
# age         554
# sibsp       644
# parch       644
# ticket      644
# fare        644
# embarked    644
# dtype: int64

# %%
tdata[tdata['embarked']=='C'].count()
# Out:
# survived    168
# pclass      168
# name        168
# sex         168
# age         130
# sibsp       168
# parch       168
# ticket      168
# fare        168
# embarked    168
# dtype: int64

# %%
tdata[tdata['embarked']=='Q'].count()
# Out:
# survived    77
# pclass      77
# name        77
# sex         77
# age         28
# sibsp       77
# parch       77
# ticket      77
# fare        77
# embarked    77
# dtype: int64

# %%
tdata['embarked'].isna().sum()
# Out:
# 2

# %%
tdata.isna().sum()
# Out:
# survived      0
# pclass        0
# name          0
# sex           0
# age         177
# sibsp         0
# parch         0
# ticket        0
# fare          0
# embarked      2
# dtype: int64

# %%
tdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
# survived    891 non-null int64
# pclass      891 non-null int64
# name        891 non-null object
# sex         891 non-null object
# age         714 non-null float64
# sibsp       891 non-null int64
# parch       891 non-null int64
# ticket      891 non-null object
# fare        891 non-null float64
# embarked    889 non-null object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 69.7+ KB

# %%
rs.get_dummies(tdata['sex'])
# Out:
#      female  male
# 0         0     1
# 1         1     0
# 2         1     0
# 3         1     0
# 4         0     1
# 5         0     1
# 6         0     1
# 7         0     1
# 8         1     0
# 9         1     0
# 10        1     0
# 11        1     0
# 12        0     1
# 13        0     1
# 14        1     0
# 15        1     0
# 16        0     1
# 17        0     1
# 18        1     0
# 19        1     0
# 20        0     1
# 21        0     1
# 22        1     0
# 23        0     1
# 24        1     0
# 25        1     0
# 26        0     1
# 27        0     1
# 28        1     0
# 29        0     1
# ..      ...   ...
# 861       0     1
# 862       1     0
# 863       1     0
# 864       0     1
# 865       1     0
# 866       1     0
# 867       0     1
# 868       0     1
# 869       0     1
# 870       0     1
# 871       1     0
# 872       0     1
# 873       0     1
# 874       1     0
# 875       1     0
# 876       0     1
# 877       0     1
# 878       0     1
# ...

# %%
tdata.sex
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
# 5        male
# 6        male
# 7        male
# 8      female
# 9      female
# 10     female
# 11     female
# 12       male
# 13       male
# 14     female
# 15     female
# 16       male
# 17       male
# 18     female
# 19     female
# 20       male
# 21       male
# 22     female
# 23       male
# 24     female
# 25     female
# 26       male
# 27       male
# 28     female
# 29       male
#         ...
# 861      male
# 862    female
# 863    female
# 864      male
# 865    female
# 866    female
# 867      male
# 868      male
# 869      male
# 870      male
# 871    female
# 872      male
# 873      male
# 874    female
# 875    female
# 876      male
# 877      male
# 878      male
# 879    female
# 880    female
# 881      male
# 882    female
# 883      male
# 884      male
# 885    female
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# ...

# %%
from sklearn.preprocessing import LabelEncoder
lab=LabelEncoder()

# %%
tdata['sex']=lab.fit_transform(tdata['sex'])

# %%
tdata['embarked']=lab.fit_transform(tdata['embarked'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-91-8619fd4ae880> in <module>()
# ----> 1 tdata['embarked']=lab.fit_transform(tdata['embarked'])
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py in fit_transform(self, y)
#     110         """
#     111         y = column_or_1d(y, warn=True)
# --> 112         self.classes_, y = np.unique(y, return_inverse=True)
#     113         return y
#     114
#
# ~\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     208     ar = np.asanyarray(ar)
#     209     if axis is None:
# --> 210         return _unique1d(ar, return_index, return_inverse, return_counts)
#     211     if not (-ar.ndim <= axis < ar.ndim):
#     212         raise ValueError('Invalid axis kwarg specified for unique')
#
# ...

# %%
dict1={'students':['ram','ranga','mounika','madevi','madevi'],'sports':['cricket','basketball','tennis','badminton','badminton',],'subject':['python','vlsi','cn','c','c']}
a1=pd.DataFrame(dict1)
a1
# Out:
#        sports students subject
# 0     cricket      ram  python
# 1  basketball    ranga    vlsi
# 2      tennis  mounika      cn
# 3   badminton   madevi       c
# 4   badminton   madevi       c

# %%
dict1
# Out:
# {'sports': ['cricket', 'basketball', 'tennis', 'badminton', 'badminton'],
#  'students': ['ram', 'ranga', 'mounika', 'madevi', 'madevi'],
#  'subject': ['python', 'vlsi', 'cn', 'c', 'c']}

# %%
a1.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
a1[a1.duplicated()]
# Out:
#       sports students subject
# 4  badminton   madevi       c

# %%
a1.drop_duplicates(inplace)
# Out:
#        sports students subject
# 0     cricket      ram  python
# 1  basketball    ranga    vlsi
# 2      tennis  mounika      cn
# 3   badminton   madevi       c

# %%
a1
# Out:
#        sports students subject
# 0     cricket      ram  python
# 1  basketball    ranga    vlsi
# 2      tennis  mounika      cn
# 3   badminton   madevi       c
# 4   badminton   madevi       c

# %% [markdown]
# import matplotlib.pyplot as plt
# list1=[1,1.2,1.3,2,1.3,2.1,6,7,8]
# list2=[0,0.07,0.5,1.6,2,7,9,8,9.0]
# plt.scatter(list1,list2)

# %%
import sklearn

# %% [markdown]
# ## minmax scaler
# it will scale all the data point in b|w 0 to 1
# mimmax scaler formula
# Xi - min(x)

# %%
a1=rs.read_csv("https://raw.githubusercontent.com/nagamounika5/Datasets/master/Advertisement.csv")
a1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-a7230f5c310a> in <module>()
# ----> 1 a1=rs.read_csv("https://raw.githubusercontent.com/nagamounika5/Datasets/master/Advertisement.csv")
#       2 a1
#
# NameError: name 'rs' is not defined

# %%
import pandas as rs

# %%
a1=rs.read_csv("https://raw.githubusercontent.com/nagamounika5/Datasets/master/Advertisement.csv")
a1
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# 5             6    8.7   48.9       75.0    7.2
# 6             7   57.5   32.8       23.5   11.8
# 7             8  120.2   19.6       11.6   13.2
# 8             9    8.6    2.1        1.0    4.8
# 9            10  199.8    2.6       21.2   10.6
# 10           11   66.1    5.8       24.2    8.6
# 11           12  214.7   24.0        4.0   17.4
# 12           13   23.8   35.1       65.9    9.2
# 13           14   97.5    7.6        7.2    9.7
# 14           15  204.1   32.9       46.0   19.0
# 15           16  195.4   47.7       52.9   22.4
# 16           17   67.8   36.6      114.0   12.5
# 17           18  281.4   39.6       55.8   24.4
# 18           19   69.2   20.5       18.3   11.3
# ...

# %%
a1.drop(['Unnamed:0'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-e24162570f2b> in <module>()
# ----> 1 a1.drop(['Unnamed:0'],axis=1,inplace=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    2528         for axis, labels in axes.items():
#    2529             if labels is not None:
# -> 2530                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    2531
#    2532         if inplace:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    2560                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2561             else:
# -> 2562                 new_axis = axis.drop(labels, errors=errors)
#    2563             dropped = self.reindex(**{axis_name: new_axis})
#    2564             try:
#
# ...

# %%
a1
# Out:
#      Unnamed: 0  newspaper  sales
# 0             1       69.2   22.1
# 1             2       45.1   10.4
# 2             3       69.3    9.3
# 3             4       58.5   18.5
# 4             5       58.4   12.9
# 5             6       75.0    7.2
# 6             7       23.5   11.8
# 7             8       11.6   13.2
# 8             9        1.0    4.8
# 9            10       21.2   10.6
# 10           11       24.2    8.6
# 11           12        4.0   17.4
# 12           13       65.9    9.2
# 13           14        7.2    9.7
# 14           15       46.0   19.0
# 15           16       52.9   22.4
# 16           17      114.0   12.5
# 17           18       55.8   24.4
# 18           19       18.3   11.3
# 19           20       19.1   14.6
# 20           21       53.4   18.0
# 21           22       23.5   12.5
# 22           23       49.6    5.6
# 23           24       26.2   15.5
# 24           25       18.3    9.7
# 25           26       19.5   12.0
# ...

# %%
a1.head()
# Out:
#    Unnamed: 0  newspaper  sales
# 0           1       69.2   22.1
# 1           2       45.1   10.4
# 2           3       69.3    9.3
# 3           4       58.5   18.5
# 4           5       58.4   12.9

# %%
print(a1['newspaper'].min())
print(a1['newspaper'].max())
# Out:
# 0.3
# 114.0

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
m=MinMaxScaler()
m
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
m2=m.fit_transform(a1)
m2
# Out:
# array([[0.        , 0.60598065, 0.80708661],
#        [0.00502513, 0.39401935, 0.34645669],
#        [0.01005025, 0.60686016, 0.30314961],
#        [0.01507538, 0.51187335, 0.66535433],
#        [0.0201005 , 0.51099384, 0.44488189],
#        [0.02512563, 0.65699208, 0.22047244],
#        [0.03015075, 0.20404573, 0.4015748 ],
#        [0.03517588, 0.09938434, 0.45669291],
#        [0.04020101, 0.00615655, 0.12598425],
#        [0.04522613, 0.18381706, 0.35433071],
#        [0.05025126, 0.21020229, 0.27559055],
#        [0.05527638, 0.03254178, 0.62204724],
#        [0.06030151, 0.5769569 , 0.2992126 ],
#        [0.06532663, 0.06068602, 0.31889764],
#        [0.07035176, 0.40193492, 0.68503937],
#        [0.07537688, 0.46262093, 0.81889764],
#        [0.08040201, 1.        , 0.42913386],
#        [0.08542714, 0.48812665, 0.8976378 ],
#        [0.09045226, 0.15831135, 0.38188976],
#        [0.09547739, 0.16534741, 0.51181102],
#        [0.10050251, 0.46701847, 0.64566929],
# ...

# %%
m2=rs.DataFrame(m2,columns=a1.columns)
m2
# Out:
#      Unnamed: 0  newspaper     sales
# 0      0.000000   0.605981  0.807087
# 1      0.005025   0.394019  0.346457
# 2      0.010050   0.606860  0.303150
# 3      0.015075   0.511873  0.665354
# 4      0.020101   0.510994  0.444882
# 5      0.025126   0.656992  0.220472
# 6      0.030151   0.204046  0.401575
# 7      0.035176   0.099384  0.456693
# 8      0.040201   0.006157  0.125984
# 9      0.045226   0.183817  0.354331
# 10     0.050251   0.210202  0.275591
# 11     0.055276   0.032542  0.622047
# 12     0.060302   0.576957  0.299213
# 13     0.065327   0.060686  0.318898
# 14     0.070352   0.401935  0.685039
# 15     0.075377   0.462621  0.818898
# 16     0.080402   1.000000  0.429134
# 17     0.085427   0.488127  0.897638
# 18     0.090452   0.158311  0.381890
# 19     0.095477   0.165347  0.511811
# 20     0.100503   0.467018  0.645669
# 21     0.105528   0.204046  0.429134
# 22     0.110553   0.433597  0.157480
# 23     0.115578   0.227792  0.547244
# ...

# %%
a1.columns
# Out:
# Index(['Unnamed: 0', 'newspaper', 'sales'], dtype='object')

# %%
m2.head()
# Out:
#    Unnamed: 0  newspaper     sales
# 0    0.000000   0.605981  0.807087
# 1    0.005025   0.394019  0.346457
# 2    0.010050   0.606860  0.303150
# 3    0.015075   0.511873  0.665354
# 4    0.020101   0.510994  0.444882

# %%
m2
# Out:
#      Unnamed: 0  newspaper     sales
# 0      0.000000   0.605981  0.807087
# 1      0.005025   0.394019  0.346457
# 2      0.010050   0.606860  0.303150
# 3      0.015075   0.511873  0.665354
# 4      0.020101   0.510994  0.444882
# 5      0.025126   0.656992  0.220472
# 6      0.030151   0.204046  0.401575
# 7      0.035176   0.099384  0.456693
# 8      0.040201   0.006157  0.125984
# 9      0.045226   0.183817  0.354331
# 10     0.050251   0.210202  0.275591
# 11     0.055276   0.032542  0.622047
# 12     0.060302   0.576957  0.299213
# 13     0.065327   0.060686  0.318898
# 14     0.070352   0.401935  0.685039
# 15     0.075377   0.462621  0.818898
# 16     0.080402   1.000000  0.429134
# 17     0.085427   0.488127  0.897638
# 18     0.090452   0.158311  0.381890
# 19     0.095477   0.165347  0.511811
# 20     0.100503   0.467018  0.645669
# 21     0.105528   0.204046  0.429134
# 22     0.110553   0.433597  0.157480
# 23     0.115578   0.227792  0.547244
# ...

# %%
m2=m.fit_transform(a1)

# %%
import seaborn as sns

# %%
fig,(ax1,ax2)=plt.subplots(ncols=2,figsize=(9,5))

# %%
fig,(ax1,ax2)=plt.subplots(ncols=2,figsize=(9,5))
sns.kdeplot(a1['newspaper'],ax=ax1)
sns.kdeplot(a1['sales'],ax=ax1)
sns.kdeplot(a1['newspaper'],ax=ax1)
sns.kdeplot(a1['sales'],ax=ax1)
